# %%
import os
import re
from bs4 import BeautifulSoup

# %% [markdown]
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Janeiro',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Fevereiro',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Marco',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Abril',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Maio',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Junho',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Julho',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Agosto',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Setembro',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Outubro',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Novembro',
# 'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Dezembro'

# %%
# Caminho para a pasta de descompactados ASC
pasta_conversa = [ 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Janeiro',
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Fevereiro',
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Marco',
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Abril',
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Maio',
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Junho', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Julho', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Agosto', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Setembro', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Outubro', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Novembro', 
'D:\ASC_Atendimentos_Descompactados/2021_2022/2022/Dezembro'
]

def extrair_anexos_arquivo(caminho_arquivo):
    anexos_encontrados = []
    try:
        with open(caminho_arquivo, 'r', encoding='latin-1') as file:
            contents = file.read()
        soup = BeautifulSoup(contents, 'html.parser')

        # Encontrar todos os links para anexos
        links_anexos = soup.find_all('a', href=True)

        for link in links_anexos:
            href = link['href']
            if 'anexos/' in href:
                caminho_anexo_origem = os.path.join(os.path.dirname(caminho_arquivo), href)
                anexos_encontrados.append(caminho_anexo_origem)

    except Exception as e:
        print(f"Ocorreu um erro ao processar o arquivo {caminho_arquivo}: {str(e)}")

    return anexos_encontrados

def extrair_informacoes_arquivo(caminho_arquivo):
    try:
        with open(caminho_arquivo, 'r', encoding='latin-1') as file:
            contents = file.read()
        soup = BeautifulSoup(contents, 'html.parser')

        info_element = soup.find('p')
        if info_element:
            info_text = info_element.get_text(strip=True)
        else:
            info_text = ""

        mensagens = []
        mensagem_elements = soup.find_all('li', class_=["agente", "contato"])
        for mensagem in mensagem_elements:
            time_element = mensagem.find('span', class_='time')
            if time_element:
                time = time_element.get_text(strip=True)
                mensagem_text_element = mensagem.find('p')
                if mensagem_text_element:
                    mensagem_text = mensagem_text_element.get_text(strip=True)
                    mensagens.append({"horario": time, "mensagem": mensagem_text, 'arquivo': caminho_arquivo})

        return {"info_conversa": info_text, "mensagens": mensagens}
    except Exception as e:
        print(f"Ocorreu um erro ao processar o arquivo {caminho_arquivo}: {str(e)}")
        return {"info_conversa": "", "mensagens": []}

def processar_pasta(pasta_conversas):
    print("Procurando em:", pasta_conversas)
    arquivos_html = [os.path.join(pasta_conversas, arquivo) for arquivo in os.listdir(pasta_conversas) if arquivo.endswith('.html')]
    
    json_data = set()  
    for arquivo_html in arquivos_html:
        encontrou_correspondencia = False  
        
        informacoes_arquivo = extrair_informacoes_arquivo(arquivo_html)
        for mensagem in informacoes_arquivo["mensagens"]:
            texto = mensagem["horario"] + mensagem["mensagem"]
            if re.search(r'DEOCLECIO AUGOSTINHO DE LEMOS|403(\.|)077(\.|)158-09', texto, re.I):
                encontrou_correspondencia = True
                json_data.add(mensagem['arquivo'])
                # Print do arquivo encontrado
                print(mensagem['arquivo'])
                #print("Horário:", mensagem["horario"])
                #print("Mensagem:", mensagem["mensagem"])
                print()
                
                # Listar caminhos dos anexos encontrados apenas nas conversas correspondentes
                anexos_arquivo = extrair_anexos_arquivo(arquivo_html)
                for anexo in anexos_arquivo:
                    print("Caminho do anexo:", anexo)
                
                break  
                
        if encontrou_correspondencia:
            continue  
        
    json_data_new = list(json_data)
    for item in json_data_new:
        print(item)

for pasta in pasta_conversa:
    processar_pasta(pasta)
# Out:
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Janeiro
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Fevereiro
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Marco
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Abril
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio
# /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/1011143-202201011143-20230810.html
#
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/7CDC042ED21F11ECAB420017A4770038-037718001653490116.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/3EA0E83FD21F11ECAB420017A4770038-369856001653490116.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/11992DBDD21F11ECAB420017A4770038-696939001653490116.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/81BDCD56D21F11ECAB420017A4770038-048287001653490117.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/4D96AAC0D21F11ECAB420017A4770038-396293001653490117.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/30C20ACCD21F11ECAB420017A4770038-723015001653490117.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/6DC072D8D21F11ECAB420017A4770038-191216001653490118.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/1E2EEB3BD21F11ECAB420017A4770038-502658001653490118.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/5B7B2747D21F11ECAB420017A4770038-800910001653490118.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/02F0DAB1D21F11ECAB420017A4770038-164372001653490119.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/11992DBDD21F11ECAB420017A4770038-206101001653490126.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/EF70FC54D21E11ECAB420017A4770038-555967001653490126.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/BEDD86EDD21E11ECAB420017A4770038-910693001653490126.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/CF1A2F9AD21E11ECAB420017A4770038-322627001653490127.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/C3F1CD851FA8A0E55E2157519928B2C2.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/964ECD6F5FC1DF9FE86F468ECB92A785.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/1CACE1657346FF6EB31AE92CBEF93E22.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/E45FC3D406C6494991B7611D7F932983.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/1EFFCB7C24DA96955467B53966D10FA5.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/544EA97CF0E9536BC43BA00CEEA5FCF7.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/28B3EF0740A5A61A4C2E6CEE8474AF02.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/72B1DB5949DC95548F9DC31451D615C0.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/B829DD811D5D26AF8BCA9A8FDD1C13C9.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/4EAEDCB657595AB2C0375506CEC8F9DF.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/139B1D255EB23F68105A3A6DD1D48966.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/3D546646CB7993EA747D63F29D6396C1.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/E91CCC6B2229828C5A96868995546C40.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/39734C384E66C1D5ECA500C67D01DBDD.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/77122418BC1529B9468F7E171AAF5697.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/409314227123A910E947A66FF3354367.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/IMAGE-928370001654172257.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/IMAGE-755204001654184558.png
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/3E0C1BE55E78139ED8245164691C2559.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/88DA4CFA5FDE83ACE4002096BA4179EB.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/1219CA76765BA85418465582EBB9143E.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/D6A21ECE8EBB02EEAA6CEE5A755C8118.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/FC96292D0FA4E2A67672332E3C941A2F.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/F13B1618D1D7E5F5990E3178892991A7.jpeg
# Caminho do anexo: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/anexos/EXC1219-266709001654197204.pdf
# /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Maio/1011143-202201011143-20230810.html
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Junho
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Julho
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Agosto
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Setembro
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Outubro
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Novembro
# Procurando em: /Volumes/Backup/ASC_Atendimentos_Descompactados/2021_2022/2022/Dezembro
